# %%
import sys, platform
print(sys.executable)
print(sys.version)
print(platform.platform())
assert ".venv" in sys.executable.lower()
# Out:
# c:\Users\pc\Desktop\info\Fraimel\Posgrado\Modulo #3\INF-8239 Ciencia de Datos II C2\practicas\.venv\Scripts\python.exe
# 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]
# Windows-11-10.0.26200-SP0
